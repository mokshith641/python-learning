# %%
print("hello")
# Out:
# hello

# %%
2*7
# Out:
# 14

# %%
day="Wednesday"

# %%
day
# Out:
# 'Wednesday'

# %%
name='luffy'

# %%
name1,name2,="kid","law"

# %%
name2
# Out:
# 'law'

# %%
bounty=100

# %%
bounty
# Out:
# 100

# %%
new_bounty=bounty+150

# %%
new_bounty
# Out:
# 250

# %%
name="luffy"
age=18
hoby="exploring"
friends=['zoro','sanji','robin']
is_bad=False

# %%
is_bad
# Out:
# False

# %%
name
# Out:
# 'luffy'

# %%
age
# Out:
# 18

# %%
friends
# Out:
# ['zoro', 'sanji', 'robin']

# %%
type(friends)
# Out:
# list

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
type(is_bad)
# Out:
# bool

# %%
 one_hundredth=1e2

# %%
one_hundredth
# Out:
# 0.01

# %%
 one_hundredth=1e-2

# %%
45e-2
# Out:
# 0.45

# %%
34e-1
# Out:
# 3.4

# %%
type(3*8)
# Out:
# int

# %%
type(3*8.0)
# Out:
# float

# %%
type(8/3)
# Out:
# float

# %%
hoby
# Out:
# 'exploring'

# %%
type(8//3)
# Out:
# int

# %%
bool([])
# Out:
# False

# %%
bool(friends)
# Out:
# True

# %%
brain=0

# %%
bool(brain)
# Out:
# False

# %%
brain=1

# %%
bool(brain)
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
mlt="""a
b"""
mlt
# Out:
# 'a\nb'

# %%
mltn="""thre's college in Mangalore"""

# %%
mltn
# Out:
# "thre's college in Mangalore"

# %%
list(mlt)
# Out:
# ['a', '\n', 'b']

# %%
list(mltn)
# Out:
# ['t',
#  'h',
#  'r',
#  'e',
#  "'",
#  's',
#  ' ',
#  'c',
#  'o',
#  'l',
#  'l',
#  'e',
#  'g',
#  'e',
#  ' ',
#  'i',
#  'n',
#  ' ',
#  'M',
#  'a',
#  'n',
#  'g',
#  'a',
#  'l',
#  'o',
#  'r',
#  'e']

# %%
day
# Out:
# 'Wednesday'

# %%
day[0]
# Out:
# 'W'

# %%
day[5]
# Out:
# 's'

# %%
day[0:9]
# Out:
# 'Wednesday'

# %%
day[0:8]
# Out:
# 'Wednesda'

# %%
day[6:9]
# Out:
# 'day'

# %%
day in day
# Out:
# True

# %%
'wed'in day
# Out:
# False

# %%
'Wed' in day
# Out:
# True

# %%
'eday' in day
# Out:
# False

# %%
fNamne='Thomas'
Sname='shelby'

# %%
fNamne+Sname
# Out:
# 'Thomasshelby'

# %%
fNamne+''+Sname
# Out:
# 'Thomasshelby'

# %%
fNamne+' '+Sname
# Out:
# 'Thomas shelby'

# %%
fNamne+' '+Sname+"pk"
# Out:
# 'Thomas shelbypk'

# %%
day.lower()
# Out:
# 'wednesday'

# %%
day.upper()
# Out:
# 'WEDNESDAY'

# %%
'dayyy'.capitalize()
# Out:
# 'Dayyy'

# %%
day.capitalize()
# Out:
# 'Wednesday'

# %%
day.lower()
# Out:
# 'wednesday'

# %%
day.replace("fri","wednes")
# Out:
# 'Wednesday'

# %%
a_da=day.replace("Wednes","fri")

# %%
a_da
# Out:
# 'friday'

# %%
another_day=a_da.replace("fri","thurs")

# %%
another_day
# Out:
# 'thursday'

# %%
name2
# Out:
# 'law'

# %%
name1
# Out:
# 'kid'

# %%
name3=name1.replace("kid","eustus kid")

# %%
name3
# Out:
# 'eustus kid'

# %%
mltn
# Out:
# "thre's college in Mangalore"

# %%
mltn.split("e")
# Out:
# ['thr', "'s coll", 'g', ' in Mangalor', '']

# %%
string1="a,man,walks,5km,towards,east,with,his,women"

# %%
string1
# Out:
# 'a,man,walks,5km,towards,east,with,his,women'

# %%
list(string1)
# Out:
# ['a',
#  ',',
#  'm',
#  'a',
#  'n',
#  ',',
#  'w',
#  'a',
#  'l',
#  'k',
#  's',
#  ',',
#  '5',
#  'k',
#  'm',
#  ',',
#  't',
#  'o',
#  'w',
#  'a',
#  'r',
#  'd',
#  's',
#  ',',
#  'e',
#  'a',
#  's',
#  't',
#  ',',
#  'w',
#  'i',
#  't',
#  'h',
#  ',',
#  'h',
#  'i',
#  's',
#  ',',
#  'w',
#  'o',
#  'm',
#  'e',
#  'n']

# %%
string1.split(",")
# Out:
# ['a', 'man', 'walks', '5km', 'towards', 'east', 'with', 'his', 'women']

# %%
string1
# Out:
# 'a,man,walks,5km,towards,east,with,his,women'

# %%
list1=string1.split(",")

# %%
list1
# Out:
# ['a', 'man', 'walks', '5km', 'towards', 'east', 'with', 'his', 'women']

# %%
string2="               A man walks 5 km towards east with his women"

# %%
string__=string2.strip()

# %%
len(string__)
# Out:
# 44

# %%
string2
# Out:
# '               A man walks 5 km towards east with his women'

# %%
cost_of_bag=1.25
profit_margin=0.2
no_bags=500

# %%
output_tamplate="""if a grocery store sells item at ${} per bag the total profit for {} bags are {}"""

# %%
tot_profit=cost_of_bag*profit_margin*no_bags

# %%
output_message=output_tamplate.format(cost_of_bag,no_bags,tot_profit)

# %%
print(output_message)
# Out:
# if a grocery store sells item at $1.25 per bag the total profit for 500 bags are 125.0

# %%
fruits=['apple','banana','mango','orrange']

# %%
fruits
# Out:
# ['apple', 'banana', 'mango', 'orrange']

# %%
fruits[3]
# Out:
# 'orrange'

# %%
len(fruits)
# Out:
# 4

# %%
aList=['luffy',18,friends,fruits]

# %%
aList
# Out:
# ['luffy',
#  18,
#  ['zoro', 'sanji', 'robin'],
#  ['apple', 'banana', 'mango', 'orrange']]

# %%
fruits
# Out:
# ['apple', 'banana', 'mango', 'orrange']

# %%
fruits[2]='blueberry'

# %%
fruits
# Out:
# ['apple', 'banana', 'blueberry', 'orrange']

# %%
fruits.append('banana')

# %%
fruits
# Out:
# ['apple', 'banana', 'blueberry', 'orrange', 'banana']

# %%
fruits.append('mango')

# %%
fruits
# Out:
# ['apple', 'banana', 'blueberry', 'orrange', 'banana', 'mango']

# %%
fruits.insert(1,'avagado')

# %%
fruits
# Out:
# ['apple', 'avagado', 'banana', 'blueberry', 'orrange', 'banana', 'mango']

# %%
fruits.remove('banana')

# %% [raw]
# fruits

# %% [raw]
# fruits

# %%
fruits.remove('apple')

# %%
fruits
# Out:
# ['avagado', 'blueberry', 'orrange', 'banana', 'mango']

# %%
fruits.append('apple')

# %% [raw]
# fruits

# %%
fruits
# Out:
# ['avagado', 'blueberry', 'orrange', 'banana', 'mango', 'apple']

# %%
fruits.pop(5)
# Out:
# 'apple'

# %% [raw]
# fruits

# %%
fruits
# Out:
# ['avagado', 'blueberry', 'orrange', 'banana', 'mango']

# %%
fruits.remove('avagado')

# %%
fruits
# Out:
# ['blueberry', 'orrange', 'banana', 'mango']

# %%
fruits.pop(0)
# Out:
# 'blueberry'

# %%
fruits
# Out:
# ['orrange', 'banana', 'mango']

# %%
fruits.append("apple")

# %%
fruits
# Out:
# ['orrange', 'banana', 'mango', 'apple']

# %%
fruits.insert(0,"bluberry")

# %%
fruits
# Out:
# ['bluberry', 'orrange', 'banana', 'mango', 'apple']

# %%
fruitss=fruits+['pineapple','guava']+['pomogranate','chiku']

# %%
fruits
# Out:
# ['bluberry', 'orrange', 'banana', 'mango', 'apple']

# %%
fruitss
# Out:
# ['bluberry',
#  'orrange',
#  'banana',
#  'mango',
#  'apple',
#  'pineapple',
#  'guava',
#  'pomogranate',
#  'chiku']

# %%
fruits=('apple','mango','orrange')

# %%
fruits
# Out:
# ('apple', 'mango', 'orrange')

# %%
len(fruits)
# Out:
# 3

# %%
fruits[1]
# Out:
# 'mango'

# %%
'apple'in fruits
# Out:
# True

# %%
fruits[-1]
# Out:
# 'orrange'

# %%
person1=dict(name='luffy',age=20,adress="east blue",status="emperor of the sea")

# %%
person1
# Out:
# {'name': 'luffy',
#  'age': 20,
#  'adress': 'east blue',
#  'status': 'emperor of the sea'}

# %%
type(person1)
# Out:
# dict

# %%
list(person1)
# Out:
# ['name', 'age', 'adress', 'status']

# %%
person1
# Out:
# {'name': 'luffy',
#  'age': 20,
#  'adress': 'east blue',
#  'status': 'emperor of the sea'}

# %%
person2={'name':'zoro','age':20,'adress':'east blue','status':'swordsman'}

# %%
person2
# Out:
# {'name': 'zoro', 'age': 20, 'adress': 'east blue', 'status': 'swordsman'}

# %%
type(person2)
# Out:
# dict

# %%
list(person2)
# Out:
# ['name', 'age', 'adress', 'status']

# %%
person2['name']
# Out:
# 'zoro'

# %% [raw]
# person1['name']

# %%
person1['name']
# Out:
# 'luffy'

# %%
person1['age']
# Out:
# 20

# %%
person1.get('name')
# Out:
# 'luffy'

# %%
person1.get('c')

# %%
person1['aim']='king of the pirates'

# %%
person1
# Out:
# {'name': 'luffy',
#  'age': 20,
#  'adress': 'east blue',
#  'status': 'emperor of the sea',
#  'aim': 'king of the pirates'}

# %%
person1.keys()
# Out:
# dict_keys(['name', 'age', 'adress', 'status', 'aim'])

# %%
person1.values()
# Out:
# dict_values(['luffy', 20, 'east blue', 'emperor of the sea', 'king of the pirates'])

# %%
person1.items()
# Out:
# dict_items([('name', 'luffy'), ('age', 20), ('adress', 'east blue'), ('status', 'emperor of the sea'), ('aim', 'king of the pirates')])

# %%
person1.items()
# Out:
# dict_items([('name', 'luffy'), ('age', 20), ('adress', 'east blue'), ('status', 'emperor of the sea'), ('aim', 'king of the pirates')])

# %%
person1.get('age')
# Out:
# 20

# %%
line = '*'
max_length=5
while len(line)<=max_length:
    print(line)
    line+="*"
# Out:
# *
# **
# ***
# ****
# *****

# %%
line = "*"
max_length=5
while len(line)<=max_length:
    print(line)
    line +="*"
    
while len(line)>0:
    print(line)
    line=line[:-1]

# %%
name='mokshith'

# %%
name[::-1]
# Out:
# 'htihskom'

# %%
name
# Out:
# 'mokshith'

# %%
nameeee=name[:-3]

# %%
nameeee
# Out:
# 'moksh'

# %%
line = "*"
max_length=5
while len(line)<=max_length:
    print(line)
    line +="*"
while len(line)>0:
    print(line)
    line=line[:-1]
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *****
# ****
# ***
# **
# *

# %%
sdf="sdfghjklsdrfghjkl"

# %%
sdf=sdf[::-1]

# %%
sdf
# Out:
# 'lkjhgfrdslkjhgfds'

# %%
line="*"
maxx=10
while len(line)<=maxx:
    print(line)
    line+="*"
while len(line)>0:
    print(line)
    line=line[:-1]
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
# ***********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *
